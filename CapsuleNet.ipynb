# %% [markdown]
# Mount the Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Navigate to the main folder of Capsule Forensic where all files and folders are stored.

# %% [markdown]
# Navigate to the directory containing the training files

# %%
# %cd /content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2
# Out:
# /content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2

# %% [markdown]
# List all the directories to cross check.

# %%
# !ls
# Out:
#  CapsuleNet.ipynb		     test_binary_ffpp_otherdata.py
#  checkpoints			     test_binary_ffpp.py
# 'Copy of Empty folder check.ipynb'   test_multiclass_detail_ffpp.py
#  databases			     test_vid_binary_ffpp.py
#  FF++				     test_vid_multiclass_ffpp.py
#  Frames_of_Videos		     train_binary_ffpp_10percent_dropout.py
#  LICENSE			     train_binary_ffpp_20percent_dropout.py
#  model_big.py			    'train_binary_ffpp_5 percent_dropout.py'
#  __pycache__			     Untitled0.ipynb
#  README.md			     Untitled1.ipynb

# %% [markdown]
# Evaluation results of the Network with the dropout of 10%

# %%
# !python test_binary_ffpp.py
# Out:
# Namespace(batchSize=32, dataset='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/databases/faceforensicspp', gpu_id=0, id=21, imageSize=300, outf='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/checkpoints/binary_faceforensicspp', random=False, test_set='test', workers=0)
# 100% 253/253 [1:24:31<00:00, 20.05s/it]
# [Epoch 21] Test acc: 90.73   EER: 11.19

# %% [markdown]
# Test result on unseen videos from faceforensic++ dataset.

# %%
# !python test_binary_ffpp.py
# Out:
# Namespace(batchSize=32, dataset='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/FF++', gpu_id=0, id=21, imageSize=300, outf='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/checkpoints/binary_faceforensicspp', random=False, test_set='test', workers=0)
# 100% 232/232 [1:07:57<00:00, 17.58s/it]
# [Epoch 21] Test acc: 37.17   EER: 68.33

# %% [markdown]
# Test result on unseen videos datset from different methods.

# %%
# !python test_binary_ffpp.py
# Out:
# Namespace(batchSize=32, dataset='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/databases/faceforensicspp/Frames_of_Videos', gpu_id=0, id=21, imageSize=300, outf='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/checkpoints/binary_faceforensicspp', random=False, test_set='test', workers=0)
# 100% 413/413 [3:03:31<00:00, 26.66s/it]
# [Epoch 21] Test acc: 45.99   EER: 48.24

# %% [markdown]
# Training of the Network with the dropout of 20%

# %%
# !python train_binary_ffpp_new_par.py
# Out:
# Namespace(batchSize=32, beta1=0.9, dataset='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/databases/faceforensicspp', disable_random=False, dropout=0.2, gpu_id=0, imageSize=300, lr=0.0005, manualSeed=None, niter=25, outf='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/checkpoints/binary_faceforensicspp', resume=0, train_set='train', val_set='validation', workers=0)
# Random Seed:  6436
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:02<00:00, 214MB/s]
# 100% 756/756 [7:14:55<00:00, 34.52s/it]
# [Epoch 1] Train loss: 1.6150   acc: 96.77 | Test loss: 1.5336  acc: 96.55
# 100% 756/756 [07:18<00:00,  1.72it/s]
# [Epoch 2] Train loss: 1.3823   acc: 99.92 | Test loss: 1.4717  acc: 96.09
# 100% 756/756 [07:18<00:00,  1.73it/s]
# [Epoch 3] Train loss: 1.3397   acc: 99.95 | Test loss: 2.9677  acc: 54.07
# 100% 756/756 [07:18<00:00,  1.72it/s]
# ...

# %% [markdown]
# Training of the Network with the dropout of 10%

# %%
# !python  train_binary_ffpp_10percent_dropout.py
# Out:
# Namespace(batchSize=32, beta1=0.9, dataset='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/databases/faceforensicspp', disable_random=False, dropout=0.1, gpu_id=0, imageSize=300, lr=0.0005, manualSeed=None, niter=25, outf='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/checkpoints/binary_faceforensicspp', resume=0, train_set='train', val_set='validation', workers=0)
# Random Seed:  3883
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:08<00:00, 69.2MB/s]
# 100% 756/756 [4:27:27<00:00, 21.23s/it]
# [Epoch 1] Train loss: 1.6010   acc: 96.64 | Test loss: 1.6376  acc: 93.23
# 100% 756/756 [05:19<00:00,  2.37it/s]
# [Epoch 2] Train loss: 1.3657   acc: 99.91 | Test loss: 1.4693  acc: 96.95
# 100% 756/756 [05:18<00:00,  2.38it/s]
# [Epoch 3] Train loss: 1.3333   acc: 99.85 | Test loss: 1.5552  acc: 93.42
# 100% 756/756 [05:17<00:00,  2.38it/s]
# ...

# %% [markdown]
# Training of the Network with the dropout of 5%

# %%
# !python train_binary_ffpp_1.py
# Out:
# Namespace(batchSize=32, beta1=0.9, dataset='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/databases/faceforensicspp', disable_random=False, dropout=0.05, gpu_id=0, imageSize=300, lr=0.0005, manualSeed=None, niter=25, outf='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/checkpoints/binary_faceforensicspp', resume=0, train_set='train', val_set='validation', workers=0)
# Random Seed:  6863
# 100% 756/756 [40:06<00:00,  3.18s/it]
# [Epoch 1] Train loss: 1.5681   acc: 97.58 | Test loss: 1.6007  acc: 93.11
# 100% 756/756 [05:19<00:00,  2.37it/s]
# [Epoch 2] Train loss: 1.3587   acc: 99.86 | Test loss: 1.4999  acc: 95.53
# 100% 756/756 [05:19<00:00,  2.36it/s]
# [Epoch 3] Train loss: 1.3231   acc: 99.86 | Test loss: 1.6338  acc: 90.76
# 100% 756/756 [05:20<00:00,  2.36it/s]
# [Epoch 4] Train loss: 1.3069   acc: 99.87 | Test loss: 1.4353  acc: 96.18
# 100% 756/756 [05:20<00:00,  2.36it/s]
# ...

# %% [markdown]
# Evaluation results of the Network with the dropout of 5%

# %%
# !python test_binary_ffpp.py
# Out:
# Namespace(batchSize=32, dataset='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/databases/faceforensicspp', gpu_id=0, id=21, imageSize=300, outf='/content/drive/MyDrive/Hashim/CapsuleNet/Capsule-Forensics-v2/checkpoints/binary_faceforensicspp', random=False, test_set='test', workers=0)
# 100% 253/253 [02:12<00:00,  1.91it/s]
# [Epoch 21] Test acc: 90.10   EER: 12.83
